# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = {
    'vijay': [25, 26, 27, 28, 29, 30],
    'thala': [65, 68, 70, 72, 75, 78],
    'fans': [2, 4, 6, 8, 10, 14]
}

df = pd.DataFrame(data)
df
# Out:
#    Temperature  Humidity  Rainfall
# 0           25        65         2
# 1           26        68         4
# 2           27        70         6
# 3           28        72         8
# 4           29        75        10
# 5           30        78        14

# %%
plt.scatter(df['Humidity'], df['Rainfall'])
plt.xlabel("Humidity")
plt.ylabel("Rainfall (mm)")
plt.title("Humidity vs Rainfall")
plt.show()

# %%
from sklearn.model_selection import train_test_split

X = df[['Temperature', 'Humidity']]
y = df['Rainfall']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=1
)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
new_weather = [[30, 78]]   # Temperature = 30, Humidity = 78
predicted_rain = model.predict(new_weather)

print("Predicted Rainfall (mm):", predicted_rain[0])
# Out:
# Predicted Rainfall (mm): 13.666666666666686
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

y_pred = model.predict(X_test)

print("Mean Absolute Error (MAE):", mean_absolute_error(y_test, y_pred))
print("Mean Squared Error (MSE):", mean_squared_error(y_test, y_pred))
print("R2 Score:", r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error (MAE): 0.6666666666666714
# Mean Squared Error (MSE): 0.5555555555555587
# R2 Score: 0.4444444444444413

# %%
new_weather_df = pd.DataFrame([[30, 78]], columns=['Temperature', 'Humidity'])
predicted_rain = model.predict(new_weather_df)

print("Predicted Rainfall (mm):", predicted_rain[0])
# Out:
# Predicted Rainfall (mm): 13.666666666666686

# %%
from sklearn.ensemble import RandomForestRegressor

rf_model = RandomForestRegressor(n_estimators=100, random_state=1)
rf_model.fit(X_train, y_train)

rf_predictions = rf_model.predict(X_test)

# %%
print("Linear Regression R2 Score:", r2_score(y_test, y_pred))
print("Random Forest R2 Score:", r2_score(y_test, rf_predictions))
# Out:
# Linear Regression R2 Score: 0.4444444444444413
# Random Forest R2 Score: 0.7133999999999998

# %%
rain_value = predicted_rain[0]

if rain_value < 10:
    category = "Low Rainfall"
elif rain_value < 25:
    category = "Moderate Rainfall"
else:
    category = "Heavy Rainfall"

print("Rainfall Category:", category)
# Out:
# Rainfall Category: Moderate Rainfall
